# %%
pip install spotipy --upgrade
# Out:
# Requirement already up-to-date: spotipy in /srv/conda/envs/notebook/lib/python3.6/site-packages (2.13.0)
# Requirement already satisfied, skipping upgrade: requests>=2.20.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spotipy) (2.24.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from spotipy) (1.15.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests>=2.20.0->spotipy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests>=2.20.0->spotipy) (1.25.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from requests>=2.20.0->spotipy) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-louvain
# Out:
# Requirement already satisfied: python-louvain in /srv/conda/envs/notebook/lib/python3.6/site-packages (0.14)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.6/site-packages (from python-louvain) (1.19.1)
# Requirement already satisfied: networkx in /srv/conda/envs/notebook/lib/python3.6/site-packages (from python-louvain) (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /srv/conda/envs/notebook/lib/python3.6/site-packages (from networkx->python-louvain) (4.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
import json
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from community import community_louvain
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Spotify APIの準備
client_id = '14b919219ef74e1cb29c710641f7ab01'
client_secret = 'e733d60291664f4e9233369dc8fee76c'
client_credentials_manager = spotipy.oauth2.SpotifyClientCredentials(client_id, client_secret)
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# アーティスト情報を格納するDataFrameを定義
artist_df = pd.DataFrame(columns=['artist_name','artist_ID','genre','popularity','related_artist_names'])

# %%
# 最初のアーティストを取得
name = 'Suchmos'
spotapi_out = spotify.search(q='artist:' + name, type='artist')
artist_items = spotapi_out['artists']['items'][0]
artist_id = artist_items['id']
artid_list = [artist_id]
artname_related_list = []
spotapi_out_related = spotify.artist_related_artists(artist_id)
for artname_related in spotapi_out_related['artists']:
    artname_related_list.append(artname_related['name'])
s = pd.Series([artist_items['name'], artist_items['id'], artist_items['genres'],artist_items['popularity'],artname_related_list],index=artist_df.columns)
artist_df = artist_df.append(s,ignore_index=True)

# %%
artid_list_tail = 0

for i in range(2):
    artid_list_head = artid_list_tail
    artid_list_tail = len(artid_list)
    for artid in artid_list[artid_list_head:artid_list_tail]:
        spotapi_out = spotify.artist_related_artists(artid)
        for artid_related in spotapi_out['artists']:
            artist_df_bool = artist_df['artist_ID']==artid_related['id']
            if artist_df_bool.sum()==0 and artid_related['popularity']>=50:
                # 類似のアーティストリストを作成
                spotapi_out_related = spotify.artist_related_artists(artid_related['id'])
                artname_related2_list = []
                for artname_related2 in spotapi_out_related['artists']:
                    artname_related2_list.append(artname_related2['name'])
                artid_list.append(artid_related['id'])
                s = pd.Series([artid_related['name'], artid_related['id'], artid_related['genres'], 
                               artid_related['popularity'], artname_related2_list], index=artist_df.columns)
                artist_df = artist_df.append(s,ignore_index=True)

# %%
# アーティストの関係の辞書を作る
artdic = {}
for i in range(len(artid_list)):
    artdic[artist_df.iloc[i,0]] = []
for i in range(len(artid_list)):
    for artname_related in artist_df.iloc[i,4]:
        artdic[artist_df.iloc[i,0]].append(artname_related)

# %%
plt.figure(figsize = (40, 40))
g = nx.Graph(artdic)
nx.draw(g, with_labels = True, 
        node_size = [120 * g.degree(n) for n in g.nodes], 
        node_color = 'g',
        edge_color='b',
       font_color='k',
       font_size=15)

# %%
len(artdic)
# Out:
# 30

# %%
artdic
# Out:
# {'Suchmos': ['LUCKY TAPES',
#   'Nulbarich',
#   'D.A.N.',
#   'Yogee New Waves',
#   'Awesome City Club',
#   'TENDRE',
#   'never young beach',
#   'cero',
#   'tofubeats',
#   'Ghost like girlfriend',
#   'chelmico',
#   "I Don't Like Mondays.",
#   'Tokyo Incidents',
#   'iri',
#   'Quruli',
#   'CHIAKI SATO',
#   'FIVE NEW OLD',
#   'Tempalay',
#   "OKAMOTO'S",
#   'Lucky Kilimanjaro'],
#  'LUCKY TAPES': ['Awesome City Club',
#   'Nulbarich',
#   'Yogee New Waves',
#   'TENDRE',
#   'Suchmos',
#   'iri',
#   'FIVE NEW OLD',
#   'never young beach',
#   "I Don't Like Mondays.",
#   'AmPm',
#   'CHIAKI SATO',
#   'tofubeats',
#   'Ghost like girlfriend',
#   'cero',
#   'chelmico',
#   'mitsume',
#   'DADARAY',
#   'D.A.N.',
#   'Special Favorite Music',
#   'Lucky Kilimanjaro'],
#  'Nulbarich': ['LUCKY TAPES',
#   'Yogee New Waves',
#   'Suchmos',
#   'Ghost like girlfriend',
#   'Awesome City Club',
#   'never young beach',
#   'FIVE NEW OLD',
#   'iri',
#   'chelmico',
#   "I Don't Like Mondays.",
#   'AmPm',
#   'Lucky Kilimanjaro',
#   'tofubeats',
#   'CHIAKI SATO',
#   'TENDRE',
#   'cero',
#   'DADARAY',
#   'D.A.N.',
#   'SPiCYSOL',
#   'Genie High'],
#  'D.A.N.': ['Yogee New Waves',
#   'mitsume',
#   'cero',
#   'ROTH BART BARON',
#   'Suchmos',
#   'never young beach',
#   'TENDRE',
#   'yahyel',
#   'Okada Takuro',
#   'odol',
#   'bonobos',
#   'The fin.',
#   'South Penguin',
#   'LUCKY TAPES',
#   'CHIAKI SATO',
#   'Quruli',
#   'PAELLAS',
#   'AAAMYYY',
#   'Supercar',
#   'Tempalay'],
#  'Yogee New Waves': ['never young beach',
#   'D.A.N.',
#   'cero',
#   'LUCKY TAPES',
#   'Nulbarich',
#   'mitsume',
#   'Suchmos',
#   'Awesome City Club',
#   'ROTH BART BARON',
#   'bonobos',
#   'TENDRE',
#   'Okada Takuro',
#   'Tomita Lab.',
#   'CHIAKI SATO',
#   'Sunny Day Service',
#   'Keiichi Sokabe',
#   'Quruli',
#   'tofubeats',
#   'Lucky Kilimanjaro',
#   'mei ehara'],
#  'Awesome City Club': ['LUCKY TAPES',
#   'FIVE NEW OLD',
#   'TENDRE',
#   'Nulbarich',
#   'Yogee New Waves',
#   'Ghost like girlfriend',
#   'Suchmos',
#   'DADARAY',
#   "I Don't Like Mondays.",
#   'never young beach',
#   'cero',
#   'Shiggy Jr.',
#   'tofubeats',
#   'iri',
#   'chelmico',
#   'Lucky Kilimanjaro',
#   'CHIAKI SATO',
#   'Tempalay',
#   'SPiCYSOL',
#   'Ohashi Trio'],
#  'TENDRE': ['LUCKY TAPES',
#   'Awesome City Club',
#   'never young beach',
#   'chelmico',
#   'Suchmos',
#   'cero',
#   'Tempalay',
#   'Yogee New Waves',
#   'tofubeats',
#   'Lucky Kilimanjaro',
#   'AmPm',
#   'D.A.N.',
#   'maco marets',
#   'CHIAKI SATO',
#   'STUTS',
#   'bonobos',
#   'mitsume',
#   'KID FRESINO',
#   'Tomita Lab.',
#   'kiki vivi lily'],
#  'never young beach': ['Yogee New Waves',
#   'cero',
#   'mitsume',
#   'TENDRE',
#   'D.A.N.',
#   'LUCKY TAPES',
#   'bonobos',
#   'Suchmos',
#   'Quruli',
#   'Ohashi Trio',
#   'Nulbarich',
#   'Awesome City Club',
#   'GING NANG BOYZ',
#   'tofubeats',
#   'Sunny Day Service',
#   'Keiichi Sokabe',
#   'Tempalay',
#   'ROTH BART BARON',
#   'chelmico',
#   'Yuta Orisaka'],
#  'cero': ['never young beach',
#   'Yogee New Waves',
#   'D.A.N.',
#   'bonobos',
#   'mitsume',
#   'Ohashi Trio',
#   'ROTH BART BARON',
#   'Okada Takuro',
#   'Sunny Day Service',
#   'Keiichi Sokabe',
#   'TENDRE',
#   'KUCHIRORO',
#   'Tomita Lab.',
#   'odol',
#   'Yuta Orisaka',
#   'Tempalay',
#   'clammbon',
#   'Quruli',
#   'mei ehara',
#   'tofubeats'],
#  'tofubeats': ['TENDRE',
#   'chelmico',
#   'LUCKY TAPES',
#   'iri',
#   'Yogee New Waves',
#   'cero',
#   'never young beach',
#   'KID FRESINO',
#   'Awesome City Club',
#   'CHIAKI SATO',
#   'PUNPEE',
#   'Suchmos',
#   'Nulbarich',
#   'Mamiko Suzuki',
#   'SALU',
#   'STUTS',
#   'C.O.S.A.',
#   'EVISBEATS',
#   'Quruli',
#   'Awich'],
#  'Ghost like girlfriend': ['Nulbarich',
#   'Awesome City Club',
#   'FIVE NEW OLD',
#   'DADARAY',
#   'LUCKY TAPES',
#   "I Don't Like Mondays.",
#   'レルエ',
#   'TENDRE',
#   'Yogee New Waves',
#   'CHIAKI SATO',
#   'sui sui duck',
#   'Suchmos',
#   'Genie High',
#   'Lucky Kilimanjaro',
#   'Omoinotake',
#   'kiki vivi lily',
#   'CRCK/LCKS',
#   'odol',
#   'chelmico',
#   'AAAMYYY'],
#  'chelmico': ['TENDRE',
#   'PUNPEE',
#   'tofubeats',
#   'Mamiko Suzuki',
#   'LUCKY TAPES',
#   'maco marets',
#   'Nulbarich',
#   'Yogee New Waves',
#   'Awesome City Club',
#   'Enjoy Music Club',
#   'Lucky Kilimanjaro',
#   'iri',
#   'never young beach',
#   'odd foot works',
#   'CHIAKI SATO',
#   'C.O.S.A.',
#   'KID FRESINO',
#   'TOKYO HEALTH CLUB',
#   'kiki vivi lily',
#   'BASI'],
#  "I Don't Like Mondays.": ["SHE'S",
#   'FIVE NEW OLD',
#   'LUCKY TAPES',
#   'Awesome City Club',
#   'Ghost like girlfriend',
#   'Nulbarich',
#   'Suchmos',
#   'TENDRE',
#   'DADARAY',
#   'iri',
#   '[Alexandros]',
#   'AmPm',
#   'tofubeats',
#   'Lucky Kilimanjaro',
#   'go!go!vanillas',
#   'chelmico',
#   '04 Limited Sazabys',
#   'never young beach',
#   'Yogee New Waves',
#   'SPiCYSOL'],
#  'Tokyo Incidents': ['Sheena Ringo',
#   'EGO-WRAPPIN’',
#   'Chara',
#   'Chatmonchy',
#   'UA',
#   'Suchmos',
#   'Quruli',
#   'YUKI',
#   'DADARAY',
#   'Soutaiseiriron',
#   'LOVE PSYCHEDELICO',
#   'Kaela Kimura',
#   'THE YELLOW MONKEY',
#   'Sakanaction',
#   'GO!GO!7188',
#   'Seiko Oomori',
#   'Fujifabric',
#   'JUDY AND MARY',
#   'tofubeats',
#   'Ohashi Trio'],
#  'iri': ['LUCKY TAPES',
#   'tofubeats',
#   'Nulbarich',
#   'Awesome City Club',
#   'chelmico',
#   'TENDRE',
#   'Yogee New Waves',
#   "I Don't Like Mondays.",
#   'SPiCYSOL',
#   'AmPm',
#   'Lucky Kilimanjaro',
#   'never young beach',
#   'Suchmos',
#   'CHIAKI SATO',
#   'KID FRESINO',
#   'SALU',
#   'PUNPEE',
#   'BASI',
#   'Shin Sakiura',
#   'DADARAY'],
#  'Quruli': ['Supercar',
#   'Sunny Day Service',
#   'never young beach',
#   'GING NANG BOYZ',
#   'Yogee New Waves',
#   'Keiichi Sokabe',
#   'cero',
#   'Fujifabric',
#   'bonobos',
#   'Soutaiseiriron',
#   'Yuta Orisaka',
#   'Number Girl',
#   'CHIAKI SATO',
#   'TRICERATOPS',
#   'clammbon',
#   'syrup16g',
#   'SUPER BUTTER DOG',
#   'Chatmonchy',
#   'Humbert Humbert',
#   'D.A.N.'],
#  'CHIAKI SATO': ['LUCKY TAPES',
#   'TENDRE',
#   'Yogee New Waves',
#   'Ghost like girlfriend',
#   'tofubeats',
#   'AAAMYYY',
#   'Lucky Kilimanjaro',
#   'Tomita Lab.',
#   'Awesome City Club',
#   'chelmico',
#   'Nulbarich',
#   'Yuta Orisaka',
#   'Tempalay',
#   'kiki vivi lily',
#   'odol',
#   'D.A.N.',
#   'Quruli',
#   'cero',
#   'never young beach',
#   'bonobos'],
#  'FIVE NEW OLD': ['Awesome City Club',
#   'LUCKY TAPES',
#   "I Don't Like Mondays.",
#   'Nulbarich',
#   'Ghost like girlfriend',
#   'go!go!vanillas',
#   'Suchmos',
#   'Unchain',
#   'DADARAY',
#   'Yogee New Waves',
#   'iri',
#   'AmPm',
#   'SPiCYSOL',
#   'TENDRE',
#   'tofubeats',
#   'RAMMELLS',
#   'the engy',
#   'THE CHARM PARK',
#   'NEIGHBORS COMPLAIN',
#   'Sunrise In My Attache Case'],
#  'Tempalay': ['TENDRE',
#   'kiki vivi lily',
#   'TENDOUJI',
#   'cero',
#   'never young beach',
#   'odol',
#   'Lucky Kilimanjaro',
#   'Yuta Orisaka',
#   'Awesome City Club',
#   'odd foot works',
#   'Sunny Day Service',
#   'CHIAKI SATO',
#   'Yogee New Waves',
#   'Ayano Kaneko',
#   'Hitsujibungaku',
#   'AAAMYYY',
#   'clammbon',
#   'domico',
#   'D.A.N.',
#   'mitsume'],
#  "OKAMOTO'S": ['THE BAWDIES',
#   'Fujifabric',
#   'the telephones',
#   'Straightener',
#   'Base Ball Bear',
#   'andymori',
#   '9mm Parabellum Bullet',
#   'ACIDMAN',
#   'the HIATUS',
#   'The Birthday',
#   'Number Girl',
#   'Unchain',
#   'Thee Michelle Gun Elephant',
#   'Chatmonchy',
#   '10-FEET',
#   'THE NOVEMBERS',
#   'Creep Hyp',
#   'Doping Panda',
#   'Wasureranneyo',
#   'BEAT CRUSADERS'],
#  'Lucky Kilimanjaro': ['TENDRE',
#   'Omoinotake',
#   'Mizuki Ohira',
#   'Yogee New Waves',
#   'chelmico',
#   'Asako Toki',
#   'Hitsujibungaku',
#   'Nulbarich',
#   'AAAMYYY',
#   'Awesome City Club',
#   'Shin Sakiura',
#   'CHIAKI SATO',
#   'Tempalay',
#   'domico',
#   'THREE1989',
#   'the engy',
#   'SPiCYSOL',
#   'Ghost like girlfriend',
#   'LUCKY TAPES',
#   'never young beach']}
